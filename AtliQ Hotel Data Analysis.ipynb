# %% [markdown]
# # IMPORT LIBRARIES

# %%
import pandas as pd

# %% [markdown]
# # DATA IMPORT AND DATA EXPLORATION

# %% [markdown]
# **Reading Booking data in a DataFrame**

# %%
df_bookings = pd.read_csv(r"C:\Users\anand\OneDrive\Desktop\AtliQ Hotel Data Analysis Project\datasets\fact_bookings.csv")

# %% [markdown]
# **Exploring the bookings data**

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %% [markdown]
# **Reading the rest of files**

# %%
df_date = pd.read_csv(r"C:\Users\anand\OneDrive\Desktop\AtliQ Hotel Data Analysis Project\datasets\dim_date.csv")
df_hotels = pd.read_csv(r"C:\Users\anand\OneDrive\Desktop\AtliQ Hotel Data Analysis Project\datasets\dim_hotels.csv")
df_rooms = pd.read_csv(r"C:\Users\anand\OneDrive\Desktop\AtliQ Hotel Data Analysis Project\datasets\dim_rooms.csv")
df_agg_bookings = pd.read_csv(r"C:\Users\anand\OneDrive\Desktop\AtliQ Hotel Data Analysis Project\datasets\fact_aggregated_bookings.csv")

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.head(5)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# ***
# **Exploring aggregate bookings**
# ***

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %% [markdown]
# Unique Property IDs

# %%
df_agg_bookings["property_id"].unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560], dtype=int64)

# %% [markdown]
# Total Successful bookings per property id

# %%
df_agg_bookings.groupby("property_id")["successful_bookings"].sum()
# Out:
# property_id
# 16558    3153
# 16559    7338
# 16560    4693
# 16561    4418
# 16562    4820
# 16563    7211
# 17558    5053
# 17559    6142
# 17560    6013
# 17561    5183
# 17562    3424
# 17563    6337
# 17564    3982
# 18558    4475
# 18559    5256
# 18560    6638
# 18561    6458
# 18562    7333
# 18563    4737
# 19558    4400
# 19559    4729
# 19560    6079
# 19561    5736
# 19562    5812
# 19563    5413
# Name: successful_bookings, dtype: int64

# %% [markdown]
# Finding out Bookings more than capacity

# %%
df_agg_bookings[df_agg_bookings["successful_bookings"]>df_agg_bookings["capacity"]]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %% [markdown]
# Finding Maximum capacity Properties

# %%
df_agg_bookings.capacity.max()
# Out:
# 50.0

# %%
df_agg_bookings[df_agg_bookings.capacity == df_agg_bookings.capacity.max() ]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 27          17558      1-May-22           RT2                   38      50.0
# 128         17558      2-May-22           RT2                   27      50.0
# 229         17558      3-May-22           RT2                   26      50.0
# 328         17558      4-May-22           RT2                   27      50.0
# 428         17558      5-May-22           RT2                   29      50.0
# ...           ...           ...           ...                  ...       ...
# 8728        17558     27-Jul-22           RT2                   22      50.0
# 8828        17558     28-Jul-22           RT2                   21      50.0
# 8928        17558     29-Jul-22           RT2                   23      50.0
# 9028        17558     30-Jul-22           RT2                   32      50.0
# 9128        17558     31-Jul-22           RT2                   30      50.0
#
# [92 rows x 5 columns]

# %% [markdown]
# # DATA CLEANING

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %% [markdown]
# **1.Removing Invalid Guests**

# %%
df_bookings[df_bookings["no_guests"] <= 0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %% [markdown]
# Number of guest can\'t be negative means it is invalid data error,we ignore the remove the records.

# %%
df_bookings = df_bookings[df_bookings["no_guests"] > 0]

# %%
df_bookings.shape
# Out:
# (134578, 12)

# %% [markdown]
# **2.Outliers removal in revenue generated**

# %%
df_bookings.revenue_generated.min() , df_bookings.revenue_generated.max()
# Out:
# (6500, 28560000)

# %%
df_bookings.revenue_generated.mean() , df_bookings.revenue_generated.median()
# Out:
# (15378.036937686695, 13500.0)

# %%
avg_revenue,std_revenue = df_bookings.revenue_generated.mean() , df_bookings.revenue_generated.std()

# %%
avg_revenue,std_revenue
# Out:
# (15378.036937686695, 93040.15493143328)

# %%
higher_limit = avg_revenue + 3*std_revenue
lower_limit  = avg_revenue - 3*std_revenue

# %%
higher_limit , lower_limit
# Out:
# (294498.50173198653, -263742.4278566132)

# %%
df_bookings[df_bookings["revenue_generated"] <= 0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings[df_bookings.revenue_generated > higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings = df_bookings[df_bookings.revenue_generated <= higher_limit]

# %%
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134573, 12)

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
high_limit = df_bookings.revenue_realized.mean() + 3*df_bookings.revenue_realized.std()
low_limit = df_bookings.revenue_realized.mean() - 3*df_bookings.revenue_realized.std()

# %%
low_limit,high_limit
# Out:
# (-8087.391491610155, 33479.3586618449)

# %%
df_bookings[df_bookings.revenue_realized > high_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %% [markdown]
# One Observation we can have from above dataframe is that all rooms are RT4 which means rooms are presidential suit.
# Since RT4 is a Luxurious room it is likely their rent will be higher.To make Fair analysis we need to do data
# analysis only on RT4 room types.

# %%
df_bookings[df_bookings.room_category == "RT4"].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %% [markdown]
# From above describe() we get mean and standard deviation

# %%
higher_limit_revenue_realized = 23439.308444 + 3*9048.599076
higher_limit_revenue_realized
# Out:
# 50585.105672000005

# %% [markdown]
# Here the Higher limit comes to be 50585 and in our dataframe above we can see that max value for revenue realized is 45220.
# Hence we can comclude that there is no outliers and we don't need to do any data cleaning on this particular column.

# %%
df_bookings[df_bookings.booking_id=="May012216558RT213"]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %% [markdown]
# Total Values in dataframe is 134573 . Out of which 77897 rows are null ratings .
# Since there are many rows with null rating , we should not filter these values.
# Also we should not replace this rating with mean or median ratings.

# %% [markdown]
# **3.Checking of null values in aggregate bookings.**

# %%
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
df_agg_bookings[df_agg_bookings.capacity.isna()]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22       NaN
# 14        17562      1-May-22           RT1                   12       NaN

# %%
df_agg_bookings.capacity.median()
# Out:
# 25.0

# %% [markdown]
# Replace NaN with Median Value.

# %%
df_agg_bookings.capacity.fillna(df_agg_bookings.capacity.median() , inplace = True)

# %%
df_agg_bookings.loc[[8,14]]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22      25.0
# 14        17562      1-May-22           RT1                   12      25.0

# %% [markdown]
# **4.Filtering of Records.**

# %% [markdown]
# In aggregate bookings, we are finding out records that have successful_bookings value greater than capacity. Then,we are filtering those records

# %%
df_agg_bookings[df_agg_bookings["successful_bookings"] > df_agg_bookings["capacity"]]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_agg_bookings.shape
# Out:
# (9200, 5)

# %%
df_agg_bookings= df_agg_bookings[df_agg_bookings["successful_bookings"] <= df_agg_bookings["capacity"]]
df_agg_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 4           16558      1-May-22           RT1                   18      19.0
# 5           17560      1-May-22           RT1                   28      40.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# [9194 rows x 5 columns]

# %%
df_agg_bookings.shape
# Out:
# (9194, 5)

# %% [markdown]
# # DATA TRANSFORMATION

# %%
df_agg_bookings.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0

# %% [markdown]
# **1.Creating Occupation Percentage Column**

# %%
df_agg_bookings["occu_pct"] = df_agg_bookings["successful_bookings"]/df_agg_bookings["capacity"]

# %% [markdown]
# Converting into percentage

# %%
df_agg_bookings["occu_pct"] = df_agg_bookings["occu_pct"].apply(lambda x: round(x*100,2))

# %%
df_agg_bookings.head(10)
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity  \
# 0         16559      1-May-22           RT1                   25      30.0
# 1         19562      1-May-22           RT1                   28      30.0
# 2         19563      1-May-22           RT1                   23      30.0
# 4         16558      1-May-22           RT1                   18      19.0
# 5         17560      1-May-22           RT1                   28      40.0
# 6         19558      1-May-22           RT1                   25      40.0
# 7         19560      1-May-22           RT1                   23      26.0
# 8         17561      1-May-22           RT1                   22      25.0
# 9         16560      1-May-22           RT1                   24      34.0
# 10        16561      1-May-22           RT1                   16      18.0
#
#     occu_pct
# 0      83.33
# 1      93.33
# 2      76.67
# 4      94.74
# 5      70.00
# 6      62.50
# 7      88.46
# 8      88.00
# ...

# %%
df_bookings.head(10)
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 1    May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4    May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5    May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6    May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7    May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
# 8    May012216558RT19        16558     30-04-22      1/5/2022      2/5/2022
# 9   May012216558RT110        16558     28-04-22      1/5/2022      2/5/2022
# 10  May012216558RT111        16558     29-04-22      1/5/2022      7/5/2022
# 11  May012216558RT112        16558     26-04-22      1/5/2022      2/5/2022
# 12  May012216558RT113        16558     26-04-22      1/5/2022      7/5/2022
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# ...

# %%
df_agg_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9194 entries, 0 to 9199
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          9194 non-null   int64
#  1   check_in_date        9194 non-null   object
#  2   room_category        9194 non-null   object
#  3   successful_bookings  9194 non-null   int64
#  4   capacity             9194 non-null   float64
#  5   occu_pct             9194 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 502.8+ KB

# %% [markdown]
# # INSIGHTS GENERATION

# %% [markdown]
# **1.What is Average occupancy rate in each of the  room categories ?**

# %%
df_agg_bookings.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0
#
#    occu_pct
# 0     83.33
# 1     93.33
# 2     76.67
# 4     94.74
# 5     70.00

# %%
round(df_agg_bookings.groupby("room_category")["occu_pct"].mean(),2)
# Out:
# room_category
# RT1    57.89
# RT2    58.01
# RT3    58.03
# RT4    59.28
# Name: occu_pct, dtype: float64

# %% [markdown]
# RT1, RT2 etc are difficult to understand. So,printing room categories such as Standard, Premium, Elite etc along with average occupancy percentage

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %% [markdown]
# Joining of fact_Aggregate_booking table and dim_rooms table

# %%
df_agg = pd.merge(df_agg_bookings,df_rooms,left_on = "room_category",right_on = "room_id",how = "left")

# %%
df_agg
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           16558      1-May-22           RT1                   18      19.0
# 4           17560      1-May-22           RT1                   28      40.0
# ...           ...           ...           ...                  ...       ...
# 9189        16563     31-Jul-22           RT4                   13      18.0
# 9190        16559     31-Jul-22           RT4                   13      18.0
# 9191        17558     31-Jul-22           RT4                    3       6.0
# 9192        19563     31-Jul-22           RT4                    3       6.0
# 9193        17561     31-Jul-22           RT4                    3       4.0
#
#       occu_pct room_id    room_class
# ...

# %% [markdown]
# Deleting the unwanted room_id column

# %%
df_agg.drop("room_id",axis = 1,inplace = True)

# %%
df_agg
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           16558      1-May-22           RT1                   18      19.0
# 4           17560      1-May-22           RT1                   28      40.0
# ...           ...           ...           ...                  ...       ...
# 9189        16563     31-Jul-22           RT4                   13      18.0
# 9190        16559     31-Jul-22           RT4                   13      18.0
# 9191        17558     31-Jul-22           RT4                    3       6.0
# 9192        19563     31-Jul-22           RT4                    3       6.0
# 9193        17561     31-Jul-22           RT4                    3       4.0
#
#       occu_pct    room_class
# ...

# %%
df_agg.groupby("room_class")["occu_pct"].mean().sort_values(ascending = False)
# Out:
# room_class
# Presidential    59.277925
# Premium         58.028213
# Elite           58.009756
# Standard        57.889643
# Name: occu_pct, dtype: float64

# %%
round(df_agg[df_agg["room_class"] == "Standard"].occu_pct.mean(),2)
# Out:
# 57.89

# %% [markdown]
# **2.Print Average Occupancy Rate per City**

# %%
df_hotels.head(5)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_agg.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
# 4        17560      1-May-22           RT1                   28      40.0
#
#    occu_pct room_class
# 0     83.33   Standard
# 1     93.33   Standard
# 2     76.67   Standard
# 3     94.74   Standard
# 4     70.00   Standard

# %% [markdown]
# Joining df_hotels and df_agg

# %%
df_agg = pd.merge(df_agg,df_hotels,on = "property_id")

# %%
df_agg
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           16559      1-May-22           RT2                   35      41.0
# 2           16559      1-May-22           RT3                   27      32.0
# 3           16559      1-May-22           RT4                   17      18.0
# 4           16559      2-May-22           RT1                   20      30.0
# ...           ...           ...           ...                  ...       ...
# 9189        18560     30-Jul-22           RT4                    9      15.0
# 9190        18560     31-Jul-22           RT1                   22      30.0
# 9191        18560     31-Jul-22           RT2                   34      40.0
# 9192        18560     31-Jul-22           RT3                   17      24.0
# 9193        18560     31-Jul-22           RT4                   12      15.0
#
# ...

# %%
df_agg
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           16559      1-May-22           RT2                   35      41.0
# 2           16559      1-May-22           RT3                   27      32.0
# 3           16559      1-May-22           RT4                   17      18.0
# 4           16559      2-May-22           RT1                   20      30.0
# ...           ...           ...           ...                  ...       ...
# 9189        18560     30-Jul-22           RT4                    9      15.0
# 9190        18560     31-Jul-22           RT1                   22      30.0
# 9191        18560     31-Jul-22           RT2                   34      40.0
# 9192        18560     31-Jul-22           RT3                   17      24.0
# 9193        18560     31-Jul-22           RT4                   12      15.0
#
# ...

# %%
df_agg
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           16559      1-May-22           RT2                   35      41.0
# 2           16559      1-May-22           RT3                   27      32.0
# 3           16559      1-May-22           RT4                   17      18.0
# 4           16559      2-May-22           RT1                   20      30.0
# ...           ...           ...           ...                  ...       ...
# 9189        18560     30-Jul-22           RT4                    9      15.0
# 9190        18560     31-Jul-22           RT1                   22      30.0
# 9191        18560     31-Jul-22           RT2                   34      40.0
# 9192        18560     31-Jul-22           RT3                   17      24.0
# 9193        18560     31-Jul-22           RT4                   12      15.0
#
# ...

# %%
df_agg.groupby("city")["occu_pct"].mean().sort_values(ascending = False)
# Out:
# city
# Delhi        61.507341
# Hyderabad    58.120652
# Mumbai       57.909181
# Bangalore    56.332376
# Name: occu_pct, dtype: float64

# %% [markdown]
# **3.When was occupancy better ? Weekday or Weekend ?**

# %%
df_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df_agg
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           16559      1-May-22           RT2                   35      41.0
# 2           16559      1-May-22           RT3                   27      32.0
# 3           16559      1-May-22           RT4                   17      18.0
# 4           16559      2-May-22           RT1                   20      30.0
# ...           ...           ...           ...                  ...       ...
# 9189        18560     30-Jul-22           RT4                    9      15.0
# 9190        18560     31-Jul-22           RT1                   22      30.0
# 9191        18560     31-Jul-22           RT2                   34      40.0
# 9192        18560     31-Jul-22           RT3                   17      24.0
# 9193        18560     31-Jul-22           RT4                   12      15.0
#
# ...

# %% [markdown]
# Joining of df_agg and df_date

# %%
df_agg = pd.merge(df_agg,df_date,left_on = "check_in_date",right_on = "date")

# %%
df_agg
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559     10-May-22           RT2                   25      41.0
# 1           16559     10-May-22           RT1                   18      30.0
# 2           16559     10-May-22           RT3                   20      32.0
# 3           16559     10-May-22           RT4                   13      18.0
# 4           19562     10-May-22           RT1                   18      30.0
# ...           ...           ...           ...                  ...       ...
# 6492        16563     31-Jul-22           RT4                   13      18.0
# 6493        18560     31-Jul-22           RT1                   22      30.0
# 6494        18560     31-Jul-22           RT2                   34      40.0
# 6495        18560     31-Jul-22           RT3                   17      24.0
# 6496        18560     31-Jul-22           RT4                   12      15.0
#
# ...

# %%
 df_agg.drop(columns = ["date"],inplace = True)

# %%
df_agg.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     10-May-22           RT2                   25      41.0
# 1        16559     10-May-22           RT1                   18      30.0
# 2        16559     10-May-22           RT3                   20      32.0
# 3        16559     10-May-22           RT4                   13      18.0
# 4        19562     10-May-22           RT1                   18      30.0
#
#    occu_pct    room_class  property_name category       city  mmm yy week no  \
# 0     60.98         Elite  Atliq Exotica   Luxury     Mumbai  May 22    W 20
# 1     60.00      Standard  Atliq Exotica   Luxury     Mumbai  May 22    W 20
# 2     62.50       Premium  Atliq Exotica   Luxury     Mumbai  May 22    W 20
# 3     72.22  Presidential  Atliq Exotica   Luxury     Mumbai  May 22    W 20
# 4     60.00      Standard      Atliq Bay   Luxury  Bangalore  May 22    W 20
#
#    day_type
# 0  weekeday
# 1  weekeday
# 2  weekeday
# ...

# %%
df_agg.groupby("day_type")["occu_pct"].mean().round(2)
# Out:
# day_type
# weekeday    50.88
# weekend     72.34
# Name: occu_pct, dtype: float64

# %% [markdown]
# => WeekEnd is Better Due to Holidays.

# %% [markdown]
# **4.In the month of June, what is the occupancy for different cities ?**

# %%
df_agg_jun_22 = df_agg[df_agg["mmm yy"] == "Jun 22"]

# %%
df_agg_jun_22.head(5)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        16559     10-Jun-22           RT2                   26      41.0
# 2202        16559     10-Jun-22           RT3                   20      32.0
# 2203        16559     10-Jun-22           RT4                   11      18.0
# 2204        19562     10-Jun-22           RT1                   19      30.0
#
#       occu_pct    room_class  property_name category       city  mmm yy  \
# 2200     66.67      Standard  Atliq Exotica   Luxury     Mumbai  Jun 22
# 2201     63.41         Elite  Atliq Exotica   Luxury     Mumbai  Jun 22
# 2202     62.50       Premium  Atliq Exotica   Luxury     Mumbai  Jun 22
# 2203     61.11  Presidential  Atliq Exotica   Luxury     Mumbai  Jun 22
# 2204     63.33      Standard      Atliq Bay   Luxury  Bangalore  Jun 22
#
#      week no  day_type
# 2200    W 24  weekeday
# ...

# %%
df_agg_jun_22.groupby("city")["occu_pct"].mean().sort_values(ascending = False).round(2)
# Out:
# city
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.44
# Name: occu_pct, dtype: float64

# %%
df_agg_jun_22.groupby("city")["occu_pct"].mean().sort_values(ascending = False).round(2).plot(kind = "bar",title = "Occupancy Rate in June Month")
# Out:
# <Axes: title={'center': 'Occupancy Rate in June Month'}, xlabel='city'>

# %% [markdown]
# **5: We got new data for the month of august. Appending that to existing data**

# %%
df_new_data_August = pd.read_csv(r"C:\Users\anand\OneDrive\Desktop\AtliQ Hotel Data Analysis Project\datasets\new_data_august.csv")

# %%
df_new_data_August
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
# 5        17561      Atliq Blu    Luxury     Mumbai           RT1   Standard
# 6        17564  Atliq Seasons  Business     Mumbai           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# ...

# %%
df_agg
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559     10-May-22           RT2                   25      41.0
# 1           16559     10-May-22           RT1                   18      30.0
# 2           16559     10-May-22           RT3                   20      32.0
# 3           16559     10-May-22           RT4                   13      18.0
# 4           19562     10-May-22           RT1                   18      30.0
# ...           ...           ...           ...                  ...       ...
# 6492        16563     31-Jul-22           RT4                   13      18.0
# 6493        18560     31-Jul-22           RT1                   22      30.0
# 6494        18560     31-Jul-22           RT2                   34      40.0
# 6495        18560     31-Jul-22           RT3                   17      24.0
# 6496        18560     31-Jul-22           RT4                   12      15.0
#
# ...

# %% [markdown]
# Changing th columns name.

# %%
df_new_data_August.rename(columns = {"occ%":"occu_pct"},inplace = True)

# %%
df_new_data_August
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
# 5        17561      Atliq Blu    Luxury     Mumbai           RT1   Standard
# 6        17564  Atliq Seasons  Business     Mumbai           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# ...

# %%
df_new_data_August.shape
# Out:
# (7, 13)

# %%
df_new_data_August.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occu_pct'],
#       dtype='object')

# %%
new_df_agg = pd.concat([df_agg,df_new_data_August],ignore_index = True,axis = 0)

# %%
new_df_agg.tail(7)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6497        16559     01-Aug-22           RT1                   30      30.0
# 6498        19562     01-Aug-22           RT1                   21      30.0
# 6499        19563     01-Aug-22           RT1                   23      30.0
# 6500        19558     01-Aug-22           RT1                   30      40.0
# 6501        19560     01-Aug-22           RT1                   20      26.0
# 6502        17561     01-Aug-22           RT1                   18      26.0
# 6503        17564     01-Aug-22           RT1                   10      16.0
#
#       occu_pct room_class  property_name  category       city  mmm yy week no  \
# 6497    100.00   Standard  Atliq Exotica    Luxury     Mumbai  Aug-22    W 32
# 6498     70.00   Standard      Atliq Bay    Luxury  Bangalore  Aug-22    W 32
# 6499     76.67   Standard   Atliq Palace  Business  Bangalore  Aug-22    W 32
# ...

# %%
new_df_agg.shape
# Out:
# (6504, 13)

# %% [markdown]
# **6.Printing Revenue Realized Per City**

# %%
df_bookings.head(5)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df_all_bookings = pd.merge(df_bookings,df_hotels, on = "property_id")

# %%
df_all_bookings.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi

# %%
df_all_bookings.groupby("city")["revenue_realized"].sum().sort_values(ascending = False)
# Out:
# city
# Mumbai       668569251
# Bangalore    420383550
# Hyderabad    325179310
# Delhi        294404488
# Name: revenue_realized, dtype: int64

# %% [markdown]
# **7.Printing month by month revenue**

# %%
df_all_bookings["check_in_date"].unique()
# Out:
# array(['1/5/2022', '2/5/2022', '3/5/2022', '4/5/2022', '5/5/2022',
#        '6/5/2022', '7/5/2022', '8/5/2022', '9/5/2022', '10/5/2022',
#        '11/5/2022', '12/5/2022', '13-05-22', '14-05-22', '15-05-22',
#        '16-05-22', '17-05-22', '18-05-22', '19-05-22', '20-05-22',
#        '21-05-22', '22-05-22', '23-05-22', '24-05-22', '25-05-22',
#        '26-05-22', '27-05-22', '28-05-22', '29-05-22', '30-05-22',
#        '31-05-22', '1/6/2022', '2/6/2022', '3/6/2022', '4/6/2022',
#        '5/6/2022', '6/6/2022', '7/6/2022', '8/6/2022', '9/6/2022',
#        '10/6/2022', '11/6/2022', '12/6/2022', '13-06-22', '14-06-22',
#        '15-06-22', '16-06-22', '17-06-22', '18-06-22', '19-06-22',
#        '20-06-22', '21-06-22', '22-06-22', '23-06-22', '24-06-22',
#        '25-06-22', '26-06-22', '27-06-22', '28-06-22', '29-06-22',
#        '30-06-22', '1/7/2022', '2/7/2022', '3/7/2022', '4/7/2022',
#        '5/7/2022', '6/7/2022', '7/7/2022', '8/7/2022', '9/7/2022',
# ...
